# %% [markdown]
# # Jupyter Notebook Example
# ## Subtitle
# This is an example notebook.
#
# 1. This is item 1
# 2. Next is 2
# 3. and then three

# %%
# example of cells
print('hello viewers')
# Out:
# hello viewers

# %%
import numpy as np
import matplotlib.pylab as plt
import matplotlib

# %%
# exemplo de como os notebooks mostram plots utilizando matplotlib

x = np.linspace(0, 2 * np.pi, 200)
y = np.sin(x)

fig, ax = plt.subplots()
ax.plot(x, y)
ax.grid()
plt.show()

# %% [markdown]
# ## Discussion about plot
# This plot above is amazing. We've learned 50 things:
# 1. thing 1
# 2. thing 2
